# %%
import numpy as np
import cv2
import sklearn.model_selection as sk
import pickle
from analysis import parse_protobufs
from ipdb import set_trace as debug
from os.path import basename

class struct():
    pass

def parse_data(save=True):
    path = struct()
    labels_output_map = {}
    path.data_folder = 'TeleOpVRSession_2018-02-05_15-44-11/'
    path.data_name = '_SessionStateData.proto'
    data = parse_protobufs(path)
    # example data extraction of x value of object/item 0 in training example 0: data.states[0].items[0].x
    num_examples = len(data.states) # number or screenshots
    num_items = []  # number of items in each example
    labels = []
    X_rgb = np.empty([0,299,299,3])
    X_d = np.empty([0,299,299])
    # format labels into n x 6 array
    for ida in range(len(data.states)):
        if (basename(data.states[ida].snapshot.name) == "d056d51f-c75b-4221-ae99-4779fe318309_9009.jpg"):
            print(data.states[ida].snapshot.name)
            print(data.states[ida].items)
    return
    for i in range(len(data.states)):
#         num_items.append(len(data.states[i].items))
#         img_name = str(data.states[i].snapshot.name)
#         depth_name = img_name[:-4] + '-Depth.jpg'
        khot_temp = np.zeros(55)
        #K Hot Encoding
        for j in range(len(data.states[i].items)):
            khot_temp[int(data.states[i].items[j].id)] = 1
        # read in rgb and depth images and add a new axis to them to indicate which snapshot index for each image
#         rgb_img = np.expand_dims(cv2.imread(img_name, 1), axis=0)
#         depth_img = np.expand_dims(cv2.imread(depth_name, 0), axis = 0)
#         current_label = [,int(len(data.states[i].items))]
#         current_label = np.append(current_label,khot_temp,axis = 0)
        
        labels_output_map[basename(data.states[i].snapshot.name)] = khot_temp
#         X_rgb = np.vstack([X_rgb, rgb_img])
#         X_d = np.vstack([X_d, depth_img])
    

    if save:
        save_path = 'data/'
#         np.save(save_path + "X_rgb.npy", X_rgb)
#         np.save(save_path + "X_d.npy", X_d)

#         pickle the labels for use elsewhere
        pickle.dump(labels_output_map, open(save_path + "img_name_to_khot_label_dict.p", "wb" ) )
#         np.save(save_path + "y.npy", y)

    return X_rgb, X_d, y


if __name__ == '__main__':
    X_rgb, X_d, y = parse_data(save=True)
    X = (np.concatenate((X_rgb,np.expand_dims(X_d, axis=3)), axis=3))
#     X_train, X_test, y_train, y_test = sk.train_test_split(X,y,test_size=.3, random_state=42)	# random_state=42 ensure indices are same for train/test set for X_rgb and X_d since they must match
# Out:
# TeleOpVRSession_2018-02-05_15-44-11/4833dcdf-90ff-497b-a217-cc669d66ff36_10.jpg
# [id: 13
# x: 0.46913498640060425
# y: -0.41363459825515747
# z: 1.366358757019043
# roll: -52.789695739746094
# pitch: -99.86327362060547
# yaw: 67.1304931640625
# , id: 32
# x: 0.8445751667022705
# y: -0.43860310316085815
# z: 1.593047857284546
# roll: -54.59333038330078
# pitch: -107.2007827758789
# yaw: 144.3639373779297
# , id: 45
# x: -0.24789690971374512
# y: -0.4415017068386078
# z: 1.6193645000457764
# roll: -173.2185516357422
# pitch: -161.2234344482422
# yaw: -19.244115829467773
# , id: 5
# x: -0.6743046641349792
# y: -0.42522525787353516
# z: 1.471590518951416
# roll: -52.10365676879883
# pitch: -39.41265106201172
# yaw: -45.78812026977539
# , id: 44
# x: -0.3632112145423889
# y: -0.4956323504447937
# z: 2.110816240310669
# roll: -168.80014038085938
# pitch: -145.5236358642578
# yaw: 18.862550735473633
# , id: 22
# x: 1.4098689556121826
# y: -0.42311540246009827
# z: 1.4524352550506592
# roll: 59.779781341552734
# pitch: -48.85309600830078
# yaw: 34.188804626464844
# , id: 35
# x: 0.4996924102306366
# y: -0.40801718831062317
# z: 1.3153586387634277
# roll: 107.78485870361328
# pitch: -175.6803741455078
# yaw: 14.640076637268066
# , id: 36
# x: 0.7144818305969238
# y: -0.3888890743255615
# z: 1.1416943073272705
# roll: -269.7867126464844
# pitch: -0.2285873293876648
# yaw: -91.37523651123047
# , id: 4
# x: 1.5824986696243286
# y: -0.44426506757736206
# z: 1.6444529294967651
# roll: 59.58992385864258
# pitch: -78.86959075927734
# yaw: -81.48661041259766
# , id: 10
# x: 0.8341485857963562
# y: -0.4842941164970398
# z: 2.0078766345977783
# roll: -218.17404174804688
# pitch: -44.446014404296875
# yaw: 132.21853637695312
# , id: 15
# x: 0.0007364135235548019
# y: -0.4028930366039276
# z: 1.2688366174697876
# roll: -167.23666381835938
# pitch: -107.84931945800781
# yaw: 88.08003234863281
# , id: 31
# x: 0.299603670835495
# y: -0.5029411911964417
# z: 2.177173137664795
# roll: -308.0194396972656
# pitch: -78.08613586425781
# yaw: -95.6995620727539
# , id: 27
# x: -0.10956335812807083
# y: -0.46452659368515015
# z: 1.828407645225525
# roll: 81.85680389404297
# pitch: -225.2690887451172
# yaw: 45.50674057006836
# , id: 11
# x: 0.5130172967910767
# y: -0.36242133378982544
# z: 0.9013938903808594
# roll: 162.28244018554688
# pitch: -96.251220703125
# yaw: 129.73870849609375
# , id: 41
# x: -0.6435734033584595
# y: -0.5106536149978638
# z: 2.247194528579712
# roll: -94.62211608886719
# pitch: -213.6938018798828
# yaw: -75.92367553710938
# , id: 53
# x: -0.7207461595535278
# y: -0.5031593441963196
# z: 2.1791539192199707
# roll: -92.76181030273438
# pitch: -42.82194137573242
# yaw: 69.46041107177734
# , id: 2
# x: 0.5233723521232605
# y: -0.4020671844482422
# z: 1.261338710784912
# roll: -7.555422782897949
# pitch: -65.72297668457031
# yaw: 70.95646667480469
# , id: 54
# x: 0.7729081511497498
# y: -0.46391212940216064
# z: 1.8228284120559692
# roll: -14.804719924926758
# pitch: -101.6033706665039
# yaw: -21.544471740722656
# , id: 16
# x: 0.18904206156730652
# y: -0.41680634021759033
# z: 1.3951553106307983
# roll: -14.536310195922852
# pitch: -239.9729766845703
# yaw: -104.75343322753906
# ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-32b0bccf9bf6> in <module>()
#      59
#      60 if __name__ == '__main__':
# ---> 61     X_rgb, X_d, y = parse_data(save=True)
#      62     X = (np.concatenate((X_rgb,np.expand_dims(X_d, axis=3)), axis=3))
#      63 #     X_train, X_test, y_train, y_test = sk.train_test_split(X,y,test_size=.3, random_state=42) # random_state=42 ensure indices are same for train/test set for X_rgb and X_d since they must match
#
# TypeError: 'NoneType' object is not iterable
